# %% [markdown]
# BABY NAME GENERATOR
#
# import tkinter as tk from tkinter import \* from PIL import Image,
# ImageTk
#
# window_main=tk.Tk(className=“Baby Name Generator”)
# window_main.geometry(‘600x600’)
#
# nameslist=\[“Aram”,“Aarthi”,“Babu”,“Bhavani”,“Chandru”,“Charulatha”,“Durai”,“Divya”,“Eswaran”,“Elakiya”,“Felix”,“Fathima”,
# “Guna”,“Gayathiri”,“Harish”,“Harini”,“Iyappan”,“Iswariya”,“Jeberson”,“Jeba”,“Kamal”,“Kaviya”,“Lakshmanan”,“Lakshmi”,
# “Madhan”,“Maha”,“Naresh”,“Nirmala”,“Obama”,“Oviya”,“Pandiyan”,“Preethi”,“Qabil”,“Queen”,“Ravi”,“ramya
# sri”,“Sathish”,
# “Saveetha”,“Thomas”,“Thishya”,“Udhayan”,“Uthra”,“Vikram”,“Vasantha”,“Weston”,“Wajiha”,“Xavier”,“Xena”,“Yuvaraj”,
# “Yasmin”,“Zaki”,“Zara”\]
#
# img=ImageTk.PhotoImage(Image.open(“C:\\Users\\user\\Documents\\baby\\baby.jpg”))
# l=Label(image=img) l.pack()
#
# app_label=tk.Label(window_main, text=“BABY NAME GENERATOR”, font=(‘Times
# New Roman’,50,‘bold’),foreground=“green”) app_label.place(x=130, y=20)
#
# name_label=tk.Label(window_main,text=“Please enter the letter”,
# font=(‘Arial’,20,‘bold’)) name_label.place(x=50, y=140)
#
# a_var=tk.StringVar()
# alphabet_entry=tk.Entry(window_main,font=(‘Calibri’,20,‘bold’),textvariable=a_var).place(x=350,
# y=140)
#
# def displaynamesfunc(): for i in nameslist: if
# i\[0\]\[0\].lower()==a_var.get().lower(): textarea.insert(END,(i+" "))
#
# display_button=tk.Button(window_main, font=(‘Times New
# Roman’,15,‘bold’), foreground=“blue”, text=“Generate Names”,
# command=displaynamesfunc) display_button.place(x=200, y=220)
#
# textarea_var=tk.StringVar() textarea=tk.Text(window_main,
# font=(‘Arial’,15)) textarea.place(x=30, y=340, width=540, height=140)
#
# def clearfunc(): a_var.set("“) textarea.delete(”1.0“,”end")
#
# def exitfunc(): window_main.destroy()
#
# clear_button=tk.Button(window_main,font=(‘Dubai medium’,20,‘italic’),
# foreground=“red”, background=“yellow”, text=“clear”, command=clearfunc)
# clear_button.place(x=380, y=520)
#
# exit_button=tk.Button(window_main, font=(‘Dubai meduim’,20,‘italic’),
# foreground=“red”, background=“blue”, text=“Exit”, command=exitfunc)
# exit_button.place(x=470, y=520)
#
# window_main.mainloop()
